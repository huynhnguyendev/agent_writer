# %% [markdown]
# ```text
#                          START
#                            │
#                            ▼
#                     ┌─────────────┐
#                     │   ROUTER    │
#                     │ Gemini Lite │
#                     └──────┬──────┘
#                            │
#                   ┌────────┴────────┐
#                   │                 │
#               Research           Direct
#                   │                 │
#                   ▼                 │
#            ┌──────────────┐         │
#            │   TAVILY     │         │
#            │ Parallel     │         │
#            │ Search       │         │
#            └──────┬───────┘         │
#                   │                 │
#                   ▼                 │
#            Gemini Flash-Lite        │
#            Evidence synthesis       │
#                   │                 │
#                   └────────┬────────┘
#                            ▼
#                   ┌────────────────┐
#                   │ ORCHESTRATOR   │
#                   │ Gemini Flash   │
#                   │   MAIN MODEL   │
#                   └───────┬────────┘
#                           │
#                        fanout
#                   ┌───────┼───────┐
#                   ▼       ▼       ▼
#                Worker  Worker  Worker
#                Groq    Groq    Groq
#                   │       │       │
#                   └───────┼───────┘
#                           ▼
#                    REDUCER SUBGRAPH
#                           │
#                    ┌──────┴──────┐
#                    ▼             ▼
#                 Merge       Web Image Search
#                                 │
#                          Wikimedia Commons
#                                 │
#                                 ▼
#                          Markdown Image
#                                 │
#                                 ▼
#                                END
# ```
